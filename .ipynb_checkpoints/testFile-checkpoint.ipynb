# %%
# This is a test file to try out stuff

# %%
# Testing NetworkX with gexf format
import networkx as nx
import matplotlib as plt

# %%
G = nx.MultiGraph()
G = nx.read_gexf("gexf/1.gexf")

# %%
len(G)
G.nodes
# Out:
# NodeView(('60', '2392', '107', '63', '3876', '5465', '252', '3060', '349', '40', '471', '148', '94', '1572', '316', '129', '34', '766', '437', '1362', '758'))

# %%
len(G.edges)
# Out:
# 68

# %%
nx.draw(G, with_labels=True)
